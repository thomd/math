# %% [markdown]
# ## Generating correlated random variables

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
var1 = 10 ** 2
var2 = 8 ** 2
cov = 72
cov_matrix = [[var1, cov],
              [cov, var2]]

data = pd.DataFrame(np.round(np.random.multivariate_normal([170, 85], cov_matrix, 100), decimals=1), columns=['height', 'weight'])
data
# Out:
#     height  weight
# 0    165.6    79.3
# 1    169.8    87.1
# 2    171.8    87.8
# 3    167.0    83.8
# 4    165.9    86.3
# ..     ...     ...
# 95   164.3    79.4
# 96   178.0    88.8
# 97   186.7    98.3
# 98   174.3    84.4
# 99   196.9   103.7
#
# [100 rows x 2 columns]

# %%
plt.scatter(data['height'], data['weight']);

# %%
import seaborn as sns
sns.pairplot(pd.DataFrame(data));

# %%
np.cov(np.array(data).T)
# Out:
# array([[73.81269091, 57.73416566],
#        [57.73416566, 54.97442828]])

# %%
np.corrcoef(np.array(data).T)
# Out:
# array([[1.        , 0.90633137],
#        [0.90633137, 1.        ]])

# %%
data.cov()
# Out:
#            height     weight
# height  73.812691  57.734166
# weight  57.734166  54.974428

# %% [markdown]
# # How to Create a Correlation Matrix using Pandas

# %%
import pandas as pd

data = {'A': [45,37,42,35,39],
        'B': [38,31,26,28,33],
        'C': [10,15,17,21,12]
        }

df = pd.DataFrame(data,columns=['A','B','C'])
df
# Out:
#     A   B   C
# 0  45  38  10
# 1  37  31  15
# 2  42  26  17
# 3  35  28  21
# 4  39  33  12

# %%
import seaborn as sns
sns.pairplot(df);

# %%
corrMatrix = df.corr()
corrMatrix
# Out:
#           A         B         C
# A  1.000000  0.518457 -0.701886
# B  0.518457  1.000000 -0.860941
# C -0.701886 -0.860941  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X_train = np.array([1,2,3,4,5,6]).reshape(-1,1)
y_train = np.array([2,2,4,5,7,7]).reshape(-1,1)

linr = LinearRegression()
linr.fit(X_train, y_train)
print("a={} b={}".format(linr.intercept_, linr.coef_[0]))
# Out:
# a=[0.4] b=[1.17142857]

# %%
X_test = np.array([2,4,5,7,9]).reshape(-1,1)
linr.predict(X_test)
# Out:
# array([[ 2.74285714],
#        [ 5.08571429],
#        [ 6.25714286],
#        [ 8.6       ],
#        [10.94285714]])
