# %%
x <- c(58, 59, 60, 61)
y <- c(115, 117, 120, 123)
df <- data.frame(x, y)
df
# Out:
#   x  y
# 1 58 115
# 2 59 117
# 3 60 120
# 4 61 123

# %%
plot(y, x, type="b")
# Out:
# plot without title

# %%
plot(rnorm(n = 50, mean = 0, sd = 1), rnorm(n = 50, mean = 0, sd = 1), col="red")
# Out:
# plot without title
